# %%
import pandas as pd

df = pd.read_csv('bangkok_traffy.csv')

# %%
display(df.columns)
print(df.shape)
# Out:
# Index(['ticket_id', 'type', 'organization', 'comment', 'photo', 'photo_after',
#        'coords', 'address', 'subdistrict', 'district', 'province', 'timestamp',
#        'state', 'star', 'count_reopen', 'last_activity'],
#       dtype='object')
# (787026, 16)

# %%
display(df.head())
# Out:
#      ticket_id                 type                      organization  \
# 0  2021-FYJTFP          {ความสะอาด}                        เขตบางซื่อ
# 1  2021-CGPMUN  {น้ำท่วม,ร้องเรียน}      เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2  2021-7XATFA              {สะพาน}                           เขตสาทร
# 3  2021-9U2NJT            {น้ำท่วม}    เขตบางซื่อ,ฝ่ายโยธา เขตบางซื่อ
# 4  2021-DVEWYM        {น้ำท่วม,ถนน}  เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
#
#                                              comment  \
# 0                                            ขยะเยอะ
# 1  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 3                                            น้ำท่วม
# 4  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
#
#                                                photo  \
# 0  https://storage.googleapis.com/traffy_public_b...
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# 3  https://storage.googleapis.com/traffy_public_b...
# 4  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 0                                                NaN  100.53084,13.81865
# 1  https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                NaN  100.52649,13.72060
# 3  https://storage.googleapis.com/traffy_public_b...  100.53099,13.81853
# 4                                                NaN  100.59165,13.82280
#
#                                              address subdistrict  district  \
# 0  12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...         NaN       NaN
# 1  189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2  191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 3  12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...         NaN       NaN
# 4  702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
#
#         province                      timestamp      state  star  \
# 0  กรุงเทพมหานคร  2021-09-03 12:51:09.453003+00  เสร็จสิ้น   NaN
# 1  กรุงเทพมหานคร  2021-09-19 14:56:08.924992+00  เสร็จสิ้น   4.0
# 2  กรุงเทพมหานคร  2021-09-26 05:03:52.594898+00  เสร็จสิ้น   NaN
# 3  กรุงเทพมหานคร  2021-10-14 10:45:27.713884+00  เสร็จสิ้น   NaN
# 4  กรุงเทพมหานคร  2021-12-09 12:29:08.408763+00  เสร็จสิ้น   5.0
#
#    count_reopen                  last_activity
# 0             0  2022-06-04 15:34:14.609206+00
# 1             0  2022-06-21 08:21:09.532782+00
# 2             0  2022-06-06 01:17:12.272904+00
# 3             0  2022-09-08 08:35:43.784519+00
# 4             0  2022-08-12 07:18:44.884945+00

# %%
for col in df.columns:
  print(df[df[col].isna()].shape, col)
# Out:
# (8772, 16) ticket_id
# (97, 16) type
# (571, 16) organization
# (8772, 16) comment
# (115, 16) photo
# (145717, 16) photo_after
# (0, 16) coords
# (8772, 16) address
# (566, 16) subdistrict
# (561, 16) district
# (195, 16) province
# (0, 16) timestamp
# (0, 16) state
# (512929, 16) star
# (0, 16) count_reopen
# (0, 16) last_activity

# %%
drop_na = df.dropna(subset=['type', 'organization', 'subdistrict', 'district', 'province', ])

# %%
drop_na.shape
# Out:
# (785925, 16)

# %% [markdown]
# # Clear แต่ละ column

# %% [markdown]
# ## Column province

# %%
print(drop_na['province'].unique())
print(drop_na['province'].unique().shape)
# Out:
# ['กรุงเทพมหานคร' 'นนทบุรี' 'สมุทรปราการ' 'สมุทรสาคร'
#  'จังหวัดกรุงเทพมหานคร' 'ปทุมธานี' 'นครปฐม' 'สุพรรณบุรี' 'เชียงราย'
#  'จังหวัดนครปฐม' 'จังหวัดสมุทรสาคร' 'จังหวัดชลบุรี'
#  'จังหวัดจังหวัด กรุงเทพมหานคร' 'จังหวัดสมุทรปราการ' 'จังหวัดปทุมธานี'
#  'จังหวัดนนทบุรี' 'จังหวัดพระนครศรีอยุธยา' 'จังหวัดนครศรีธรรมราช'
#  'จังหวัดฉะเชิงเทรา' 'จังหวัดชุมพร' 'ชลบุรี' 'จังหวัดBangkok'
#  'จังหวัดจังหวัดกรุงเทพมหานคร' 'จังหวัดนครสวรรค์' 'จังหวัดสงขลา' 'ลำพูน'
#  'จังหวัดจ.ฉะเชิงเทรา' 'พิษณุโลก' 'ภูเก็ต' 'นครราชสีมา' 'จังหวัดสระบุรี'
#  'ราชบุรี' 'สงขลา' 'จังหวัดประจวบคีรีขันธ์' 'สุราษฎร์ธานี' 'จังหวัดลพบุรี'
#  'เชียงใหม่' 'ยโสธร' 'กาญจนบุรี' 'พังงา' 'อุดรธานี' 'จังหวัดราชบุรี'
#  'จังหวัดเพชรบุรี' 'สุรินทร์' 'นครสวรรค์' 'ลพบุรี' 'จังหวัดจังหวัดพะเยา'
#  'จังหวัดเชียงใหม่' 'จังหวัดจังหวัด' 'บุรีรัมย์' 'พระนครศรีอยุธยา'
#  'จังหวัดจังหวัดพระนครศรีอยุธยา' 'จังหวัดกรุงเทพฯ' 'แพร่' 'ขอนแก่น'
#  'จังหวัดจ.สุพรรณบุรี' 'ประจวบคีรีขันธ์' 'เพชรบุรี' 'จังหวัดอำนาจเจริญ'
#  'ฉะเชิงเทรา' 'จังหวัดกระบี่']
# (61,)

# %%
# ลบ คำว่า จังหวัด นำหน้า
drop_na['province'] = (drop_na['province'].str.replace('จังหวัด', '', regex=False))
print(drop_na['province'].unique())
print(drop_na['province'].unique().shape)
# Out:
# /tmp/ipython-input-1800115464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_na['province'] = (drop_na['province'].str.replace('จังหวัด', '', regex=False))
# ['กรุงเทพมหานคร' 'นนทบุรี' 'สมุทรปราการ' 'สมุทรสาคร' 'ปทุมธานี' 'นครปฐม'
#  'สุพรรณบุรี' 'เชียงราย' 'ชลบุรี' ' กรุงเทพมหานคร' 'พระนครศรีอยุธยา'
#  'นครศรีธรรมราช' 'ฉะเชิงเทรา' 'ชุมพร' 'Bangkok' 'นครสวรรค์' 'สงขลา'
#  'ลำพูน' 'จ.ฉะเชิงเทรา' 'พิษณุโลก' 'ภูเก็ต' 'นครราชสีมา' 'สระบุรี'
#  'ราชบุรี' 'ประจวบคีรีขันธ์' 'สุราษฎร์ธานี' 'ลพบุรี' 'เชียงใหม่' 'ยโสธร'
#  'กาญจนบุรี' 'พังงา' 'อุดรธานี' 'เพชรบุรี' 'สุรินทร์' 'พะเยา' ''
#  'บุรีรัมย์' 'กรุงเทพฯ' 'แพร่' 'ขอนแก่น' 'จ.สุพรรณบุรี' 'อำนาจเจริญ'
#  'กระบี่']
# (43,)

# %%
province_mapping = {
    # รวมเข้ากับ 'กรุงเทพมหานคร'
    'กรุงเทพฯ': 'กรุงเทพมหานคร',
    'Bangkok': 'กรุงเทพมหานคร',

    # จัดการกับคำย่อ 'จ.'
    'จ.ฉะเชิงเทรา': 'ฉะเชิงเทรา',
    'จ.สุพรรณบุรี': 'สุพรรณบุรี',

    # จัดการกับค่าว่าง
    '': 'ไม่ระบุ' # เปลี่ยนค่าว่างเป็น 'ไม่ระบุ'
}

drop_na['province'] = drop_na['province'].replace(province_mapping)

drop_na['province'].unique()
# Out:
# /tmp/ipython-input-1125349012.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_na['province'] = drop_na['province'].replace(province_mapping)
# array(['กรุงเทพมหานคร', 'นนทบุรี', 'สมุทรปราการ', 'สมุทรสาคร', 'ปทุมธานี',
#        'นครปฐม', 'สุพรรณบุรี', 'เชียงราย', 'ชลบุรี', ' กรุงเทพมหานคร',
#        'พระนครศรีอยุธยา', 'นครศรีธรรมราช', 'ฉะเชิงเทรา', 'ชุมพร',
#        'นครสวรรค์', 'สงขลา', 'ลำพูน', 'พิษณุโลก', 'ภูเก็ต', 'นครราชสีมา',
#        'สระบุรี', 'ราชบุรี', 'ประจวบคีรีขันธ์', 'สุราษฎร์ธานี', 'ลพบุรี',
#        'เชียงใหม่', 'ยโสธร', 'กาญจนบุรี', 'พังงา', 'อุดรธานี', 'เพชรบุรี',
#        'สุรินทร์', 'พะเยา', 'ไม่ระบุ', 'บุรีรัมย์', 'แพร่', 'ขอนแก่น',
#        'อำนาจเจริญ', 'กระบี่'], dtype=object)

# %%
clean_province = drop_na

# %% [markdown]
# ## เช็คความถูกต้องของ column

# %%
for col in clean_province:
  print(col, clean_province[clean_province[col].isna()].shape)
# Out:
# ticket_id (8766, 16)
# type (0, 16)
# organization (0, 16)
# comment (8766, 16)
# photo (98, 16)
# photo_after (145061, 16)
# coords (0, 16)
# address (8766, 16)
# subdistrict (0, 16)
# district (0, 16)
# province (0, 16)
# timestamp (0, 16)
# state (0, 16)
# star (511858, 16)
# count_reopen (0, 16)
# last_activity (0, 16)

# %% [markdown]
# ⬆️⬆️⬆️⬆️ ลบ na ของ column ที่จำเป็นออกหมดแล้ว

# %% [markdown]
# ## แยก coords เป็น Lat Long

# %%
lat_long = clean_province

# %%
split_coords = lat_long['coords'].str.split(',', expand=True)

display(split_coords.head())
#latitude and longitude
lat_long['latitude'] = split_coords[1]
lat_long['longitude'] = split_coords[0]
# Out:
#            0         1
# 1  100.66709  13.67891
# 2  100.52649  13.72060
# 4  100.59165  13.82280
# 5  100.59131  13.80910
# 6  100.50848  13.77832
# /tmp/ipython-input-954863395.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_long['latitude'] = split_coords[1]
# /tmp/ipython-input-954863395.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_long['longitude'] = split_coords[0]

# %%
display(lat_long.head())
display(lat_long.tail())
# Out:
#      ticket_id                 type                              organization  \
# 1  2021-CGPMUN  {น้ำท่วม,ร้องเรียน}              เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2  2021-7XATFA              {สะพาน}                                   เขตสาทร
# 4  2021-DVEWYM        {น้ำท่วม,ถนน}          เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 5  2021-4D9Y98                   {}  เขตลาดพร้าว,การไฟฟ้านครหลวง เขตนวลจันทร์
# 6  2021-7U9RED                   {}                                  เขตดุสิต
#
#                                              comment  \
# 1  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 4  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 5                        หน้าปากซอย ลาดพร้าววังหิน26
# 6  ยังไม่มีหน่วยงานไหนมาดูแลครับ รถจะเชี่ยวหลายคน...
#
#                                                photo  \
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# 4  https://storage.googleapis.com/traffy_public_b...
# 5  https://storage.googleapis.com/traffy_public_b...
# 6  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 1  https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                NaN  100.52649,13.72060
# 4                                                NaN  100.59165,13.82280
# 5  https://storage.googleapis.com/traffy_public_b...  100.59131,13.80910
# 6  https://storage.googleapis.com/traffy_public_b...  100.50848,13.77832
#
#                                              address subdistrict  district  \
# 1  189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2  191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 4  702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 5  17/73 17/73 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขต...    ลาดพร้าว  ลาดพร้าว
# 6  627 ถนนสามเสน แขวง ดุสิต เขตดุสิต กรุงเทพมหานค...       ดุสิต     ดุสิต
#
#         province                      timestamp      state  star  \
# 1  กรุงเทพมหานคร  2021-09-19 14:56:08.924992+00  เสร็จสิ้น   4.0
# 2  กรุงเทพมหานคร  2021-09-26 05:03:52.594898+00  เสร็จสิ้น   NaN
# 4  กรุงเทพมหานคร  2021-12-09 12:29:08.408763+00  เสร็จสิ้น   5.0
# 5  กรุงเทพมหานคร  2021-12-13 05:53:36.861064+00  เสร็จสิ้น   NaN
# 6  กรุงเทพมหานคร  2021-12-17 08:46:02.610983+00  เสร็จสิ้น   5.0
#
#    count_reopen                  last_activity  latitude  longitude
# 1             0  2022-06-21 08:21:09.532782+00  13.67891  100.66709
# 2             0  2022-06-06 01:17:12.272904+00  13.72060  100.52649
# 4             0  2022-08-12 07:18:44.884945+00  13.82280  100.59165
# 5             0  2023-03-14 12:09:14.947437+00  13.80910  100.59131
# 6             0  2023-05-17 06:11:32.463984+00  13.77832  100.50848
#           ticket_id                            type  \
# 787021       KDDNBP                     {ร้องเรียน}
# 787022       RYM99G                 {ความสะอาด,ถนน}
# 787023  2025-BDQ87Y  {ร้องเรียน,ต้นไม้,ความปลอดภัย}
# 787024       EZCZZU                           {ถนน}
# 787025  2025-E7CTFD                         {จราจร}
#
#                                              organization  \
# 787021                                         เขตหนองจอก
# 787022             เขตคลองสาน,ฝ่ายสิ่งแวดล้อมฯ เขตคลองสาน
# 787023                                         เขตราชเทวี
# 787024                                          เขตจอมทอง
# 787025  เขตสวนหลวง,สำนักการจราจรและขนส่ง กรุงเทพมหานคร...
#
#                                                   comment  \
# 787021  ศูนย์เรื่องราวร้องทุกข์ ได้รับการประสานผ่านระบ...
# 787022  ปัญหา: บริเวณตลาดพระเครื่องพญาไม้ พบร้านอาหารต...
# 787023  ต้นไม้บริเวณดังกล่าวช่วงโคนต้นไม้มันแห้งเหมือน...
# 787024  ปัญหา: พบโรงกลึง (ไม่ทราบชื่อ) ทำงานบนพื้นผิวจ...
# 787025  จริงๆไม่ใช่เขตสวนหลวงแต่ที่ปักเป็นสวนหลวงเพราะ...
#
#                                                     photo photo_after  \
# 787021  https://storage.googleapis.com/traffy_public_b...         NaN
# 787022  https://storage.googleapis.com/traffy_public_b...         NaN
# 787023  https://storage.googleapis.com/traffy_public_b...         NaN
# 787024  https://storage.googleapis.com/traffy_public_b...         NaN
# 787025  https://storage.googleapis.com/traffy_public_b...         NaN
#
#                     coords                                            address  \
# 787021  100.86304,13.85633  เขตหนองจอก กรุงเทพมหานคร : VV47+G6M แขวงกระทุ่...
# 787022  100.49651,13.73469  39 ถ. สมเด็จเจ้าพระยา แขวงสมเด็จเจ้าพระยา เขตค...
# 787023  100.53975,13.76426  10 ถ. ราชวิถี แขวงถนนพญาไท เขตราชเทวี กรุงเทพม...
# 787024  100.46226,13.67672  123 แขวงบางมด เขตจอมทอง กรุงเทพมหานคร 10150 ปร...
# 787025  100.65165,13.73036  2998 ถ. พัฒนาการ แขวงสวนหลวง เขตสวนหลวง กรุงเท...
#
#             subdistrict district       province  \
# 787021       กระทุ่มราย  หนองจอก  กรุงเทพมหานคร
# 787022  สมเด็จเจ้าพระยา  คลองสาน  กรุงเทพมหานคร
# 787023         ถนนพญาไท  ราชเทวี  กรุงเทพมหานคร
# 787024            บางมด   จอมทอง  กรุงเทพมหานคร
# 787025          สวนหลวง  สวนหลวง  กรุงเทพมหานคร
#
#                             timestamp           state  star  count_reopen  \
# 787021  2025-01-16 02:50:24.112172+00  กำลังดำเนินการ   NaN             0
# 787022    2025-01-16 02:51:28.8957+00  กำลังดำเนินการ   NaN             0
# 787023  2025-01-16 02:52:33.878797+00     รอรับเรื่อง   NaN             0
# 787024  2025-01-16 02:53:27.583947+00  กำลังดำเนินการ   NaN             0
# 787025  2025-01-16 02:53:34.290375+00  กำลังดำเนินการ   NaN             0
#
#                         last_activity  latitude  longitude
# 787021  2025-01-16 02:50:26.781334+00  13.85633  100.86304
# 787022  2025-01-16 02:53:23.119455+00  13.73469  100.49651
# 787023   2025-01-16 02:52:38.17364+00  13.76426  100.53975
# 787024  2025-01-16 02:53:30.250517+00  13.67672  100.46226
# 787025  2025-01-16 02:58:02.568451+00  13.73036  100.65165

# %%
for col in lat_long.columns:
  print(col, lat_long[lat_long[col].isna()].shape)
# Out:
# ticket_id (8766, 18)
# type (0, 18)
# organization (0, 18)
# comment (8766, 18)
# photo (98, 18)
# photo_after (145061, 18)
# coords (0, 18)
# address (8766, 18)
# subdistrict (0, 18)
# district (0, 18)
# province (0, 18)
# timestamp (0, 18)
# state (0, 18)
# star (511858, 18)
# count_reopen (0, 18)
# last_activity (0, 18)
# latitude (0, 18)
# longitude (0, 18)

# %%
for col in lat_long.columns:
  print(col, lat_long[col].unique())
  print(lat_long[col].unique().shape)
# Out:
# ticket_id ['2021-CGPMUN' '2021-7XATFA' '2021-DVEWYM' ... '2025-BDQ87Y' 'EZCZZU'
#  '2025-E7CTFD']
# (777160,)
# type ['{น้ำท่วม,ร้องเรียน}' '{สะพาน}' '{น้ำท่วม,ถนน}' ... '{PM2.5,ถนน,เสนอแนะ}'
#  '{ความปลอดภัย,ป้าย,กีดขวาง,สายไฟ,ทางเท้า}'
#  '{กีดขวาง,ถนน,ทางเท้า,เสียงรบกวน}']
# (17454,)
# organization ['เขตประเวศ,ฝ่ายโยธา เขตประเวศ' 'เขตสาทร'
#  'เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว' ... 'เขตประเวศ,กรมควบคุมมลพิษ'
#  'เขตทวีวัฒนา,เขตพระโขนง' 'เขตประเวศ,ศูนย์ควบคุมระบบป้องกันน้ำท่วม กทม.']
# (70143,)
# comment ['น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆปีจะมีเครื่องสูบน้ำแต่ปีนี้ไม่มีกทม.ปล่อยทิ้ง ชุมชนเคหะนคร1แปลง2(ซ.เฉลิมพระเกียรติร.9ซอง22 วัดตะกล่ำ ประเวศ)'
#  'สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12'
#  'ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว\n\n1. หลังจากฝนตกต่อเนื่องประมาณ 30 นาที น้ำท่วมซอยสูงประมาณ 20 ซม ใช้เวลาระบายราวๆ 3-5 ชม. กว่าน้ำในซอยแห้ง\nหากฝนตกนานกว่า 1 ชม  ใช้เวลา 2-3 วัน กว่าน้ำในซอยแห้ง\nหากนานกว่านั้น ต้นซอยน้ำแห้ง ปลายซอยน้ำเน่า'
#  ...
#  'ต้นไม้บริเวณดังกล่าวช่วงโคนต้นไม้มันแห้งเหมือนต้นไม้มันตายแล้วแห้งเหมือนจะล้มลงมาเกรงว่าจะเกิดอันตรายต่อผู้สัญจรอยากให้ช่วยมาตรวจสอบแก้ไขจุดสังเกตบริเวณใกล้ปากซอยราชวิถีซอย 7'
#  'ปัญหา: พบโรงกลึง (ไม่ทราบชื่อ) ทำงานบนพื้นผิวจราจร โดยเอาเศษเหล็กมาเจียร ช่วงเวลาตั้งแต่ 08:00 -17:00 น. เป็นประจำทุกวัน ทำให้พื้นผิวถนนเกิดความสกปรก และทำให้ผู้ที่สัญจรไป-มา\nซอย: พระราม 2 ที่ 30\nถนน: พระราม 2\nจุดสังเกต: เข้าซอยดังกล่าวไปประมาณ 500 เมตร ด้านขวามือ \nเขต: จอมทอง\r\n#1555'
#  'จริงๆไม่ใช่เขตสวนหลวงแต่ที่ปักเป็นสวนหลวงเพราะผมพักอาศัยอยู่ที่เขตนี้ สิ่งที่จะพูดถึงเส้นจราจรบนพื้นถนนในทั่วกทม. ไม่มีความเข้มไม่มีการสะท้อนในเวลากลางคืน จะออกกฏมากมายตั้งกล้องเพราะจับและปรับมากมาย แต่เส้นจาง บางมองแทบไม่เห็น ทุกๆเขตในกทม. ย้ำเลยว่าจางทุกๆที่ในกทม.']
# (683304,)
# photo ['https://storage.googleapis.com/traffy_public_bucket/attachment/2021-09/41ef2b1b465b708db17363a6d5fd8c5336266df7.jpg'
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2021-09/b0b738c84fb0d0b0bfd5c5ac004492eb6fde19c3.jpg'
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2021-12/6b71a10f77a724a6151180eb5eb5bb0fc1500ce9.jpg'
#  ...
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2025-01/38fd10a622032fd235d00082d54f610916390528.jpg'
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2025-01/25eec71914ed4a0f7cc1e1b94cf388c8.jpg'
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2025-01/b90079901764000259df5fc4f23e177899cf915f.jpg']
# (777027,)
# photo_after ['https://storage.googleapis.com/traffy_public_bucket/attachment/2022-06/b562e36f971f02221bd0f32b7272eb1ea516cacf.jpg'
#  nan
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2023-03/1678795752004.jpeg'
#  ...
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2025-01/6c96609b1db0337f4ea9ab4ee5dbae1e.png'
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2025-01/3407920335a60593396c0774bff4197e.png'
#  'https://storage.googleapis.com/traffy_public_bucket/attachment/2025-01/184d011aa6f1b3fc36ab775578210ea9.jpg']
# (640863,)
# coords ['100.66709,13.67891' '100.52649,13.72060' '100.59165,13.82280' ...
#  '100.53975,13.76426' '100.46226,13.67672' '100.65165,13.73036']
# (670502,)
# address ['189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเวศ กรุงเทพมหานคร 10250 ประเทศไทย'
#  '191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเทพมหานคร 10500 ประเทศไทย'
#  '702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว กรุงเทพมหานคร 10230 ประเทศไทย'
#  ... '234 ซอย สุขุมวิท 93 บางจาก เขตพระโขนง กรุงเทพมหานคร 10260 ประเทศไทย'
#  '45 ซอย ถนน เฉลิมพระเกียรติ ร. 9 แขวงหนองบอน เขตประเวศ กรุงเทพมหานคร 10250 ประเทศไทย'
#  '123 แขวงบางมด เขตจอมทอง กรุงเทพมหานคร 10150 ประเทศไทย']
# (334942,)
# subdistrict ['หนองบอน' 'ยานนาวา' 'ลาดพร้าว' 'ดุสิต' 'ประเวศ' 'ทุ่งมหาเมฆ' 'ทุ่งวัดดอน'
#  'สวนจิตรลดา' 'ถนนนครไชยศรี' 'สายไหม' 'ถนนพญาไท' 'สีลม' 'สี่พระยา'
#  'จตุจักร' 'บางไผ่' 'บางขุนศรี' 'คลองตัน' 'คลองสองต้นนุ่น' 'ทุ่งสองห้อง'
#  'หัวหมาก' 'กระทุ่มราย' 'คลองตันเหนือ' 'ท่าแร้ง' 'คลองสาน' 'บางซื่อ'
#  'บางปะกอก' 'ดินแดง' 'บุคคโล' 'รองเมือง' 'ปทุมวัน' 'ดอกไม้' 'รามอินทรา'
#  'วังบูรพาภิรมย์' 'พระโขนง' 'บางระมาด' 'สนามบิน' 'ดาวคะนอง' 'สามเสนนอก'
#  'สะพานสูง' 'สามเสนใน' 'สวนหลวง' 'บางแวก' 'ตลาดบางเขน' 'แสมดำ'
#  'วัดพระยาไกร' 'วัดกัลยาณ์' 'บางนาเหนือ' 'ทุ่งครุ' 'บางแคเหนือ' 'บางมด'
#  'บางชัน' 'จอมพล' 'คลองต้นไทร' 'ลาดยาว' 'อนุสาวรีย์' 'คลองถนน' 'บางด้วน'
#  'บางหว้า' 'วังทองหลาง' 'ห้วยขวาง' 'สามวาตะวันออก' 'จรเข้บัว'
#  'บ้านช่างหล่อ' 'คลองเตย' 'ถนนเพชรบุรี' 'วัดท่าพระ' 'บางแค' 'ทุ่งพญาไท'
#  'สีกัน' 'เสนานิคม' 'คู้ฝั่งเหนือ' 'วงศ์สว่าง' 'คลองสามประเวศ' 'ช่องนนทรี'
#  'พระโขนงเหนือ' 'ลุมพินี' 'สำเหร่' 'บางจาก' 'บางโพงพาง' 'วัดสามพระยา'
#  'นวลจันทร์' 'ลำผักชี' 'พลับพลา' 'คลองกุ่ม' 'ลำปลาทิว' 'บางพรม' 'มักกะสัน'
#  'ออเงิน' 'หนองแขม' 'บางค้อ' 'แสนแสบ' 'บางโคล่' 'ฉิมพลี' 'ท่าข้าม'
#  'บางพลัด' 'บางบอนเหนือ' 'บางขุนเทียน' 'คลองจั่น' 'บางเชือกหนัง'
#  'บางคอแหลม' 'บวรนิเวศ' 'สะพานสอง' 'ดอนเมือง' 'ปากคลองภาษีเจริญ'
#  'คลองเจ้าคุณสิงห์' 'บางลำภูล่าง' 'อรุณอมรินทร์' 'คันนายาว'
#  'ทรายกองดินใต้' 'บางกะปิ' 'คลองเตยเหนือ' 'บางอ้อ' 'ลาดกระบัง'
#  'วัดราชบพิธ' 'บางยี่ขัน' 'หนองค้างพลู' 'มีนบุรี' 'ทับยาว' 'สัมพันธวงศ์'
#  'สามวาตะวันตก' 'คลองขวาง' 'คลองสิบ' 'พระบรมมหาราชวัง' 'สมเด็จเจ้าพระยา'
#  'ศิริราช' 'หนองจอก' 'โคกแฝด' 'บางบำหรุ' 'วัดเทพศิรินทร์' 'วัดชลอ'
#  'ศาลาธรรมสพน์' 'หิรัญรูจี' 'วัดโสมนัส' 'จันทรเกษม' 'ทับช้าง' 'มหาสวัสดิ์'
#  'คลองสิบสอง' 'บางยี่เรือ' 'ตลิ่งชัน' 'ลำต้อยติ่ง' 'คลองมหานาค' 'วังใหม่'
#  'มหาพฤฒาราม' 'ตลาดพลู' 'หลักสอง' 'สุริยวงศ์' 'ตลาดน้อย' 'ทวีวัฒนา'
#  'บ้านบาตร' 'สำราญราษฎร์' 'ทรายกองดิน' 'คลองชักพระ' 'เสาชิงช้า' 'จอมทอง'
#  'สี่แยกมหานาค' 'ราษฎร์บูรณะ' 'บางขุนนนท์' 'ป้อมปราบ' 'วชิรพยาบาล'
#  'นวมินทร์' 'บางรัก' 'บางขุนพรหม' 'วัดอรุณ' 'จักรวรรดิ' 'บ้านพานถม'
#  'ชนะสงคราม' 'ขุมทอง' 'คูหาสวรรค์' 'ศาลเจ้าพ่อเสือ' 'ตลาดยอด' 'จักรวรรดิ์'
#  'บางนา' 'พันท้ายนรสิงห์' 'ศีรษะจรเข้น้อย' 'หลักหก' 'บางบอน' 'คลองบางพราน'
#  'บางบอนใต้' 'บางนาใต้' 'คลองบางบอน' 'ท่าไม้' 'บางแก้ว' 'บางเขน'
#  'เทพารักษ์' 'บางน้ำจืด' 'ปากน้ำ' 'สำโรงกลาง' 'ท่าทราย' 'บ้านใหม่'
#  'ประชาธิปัตย์' 'บางกรวย' 'ศาลายา' 'สำโรงเหนือ' 'มดแดง' 'บางกระสอ'
#  'คลองหนึ่ง' 'ราชาเทวะ' 'บางครุ' 'ทรงคนอง' 'อ้อมน้อย' 'เวียง'
#  'ราษฎร์พัฒนา' 'บางม่วง' 'บางขนุน' 'หนองดินแดง' 'บางหญ้าแพรก' 'นาเกลือ'
#  'คลองห้า' 'กระทุ่มล้ม' 'บางตลาด' 'บางสีทอง' 'คลองสวน' 'วังไผ่' 'คูคต'
#  'ศีรษะจรเข้ใหญ่' 'ดอนฉิมพลี' 'ตลาดขวัญ' 'บางโทรัด' 'แหลมฟ้าผ่า' 'ลาดสวาย'
#  'ดอนรวก' 'นาเคียน' 'บางพลีใหญ่' 'สำโรง' 'บึงคำพร้อย' 'คลองสอง' 'สวนใหญ่'
#  'บ้านคลองสวน' 'คอกกระบือ' 'ลำลูกกา' 'บางกอบัว' 'บางกระทึก' 'บางขุนกอง'
#  'พยุหะ' 'บางคูวัด' 'หาดใหญ่' 'บางพูด' 'กาหลง' 'คลองพระอุดม' 'บางเพรียง'
#  'คลองข่อย' 'ห้วยยาบ' 'บางพึ่ง' 'บางพลับ' 'ลาดหลุมแก้ว' 'พรหมพิราม'
#  'ตลาดใหญ่' 'รัษฎา' 'ในเมือง' 'ทับกวาง' 'เจดีย์หัก' 'บ้านฉาง' 'คลองเปียะ'
#  'ประจวบคีรีขันธ์' 'บางเตย' 'บ้านหมี่' 'เชิงดอย' 'ศาลากลาง' 'สวาท'
#  'ท่าม่วง' 'พรุใน' 'เกาะยาวใหญ่' 'โพนสูง' 'นครปฐม' 'โพธาราม' 'โคกหม้อ'
#  'ดอนตะโก' 'หน้าเมือง' 'คูบัว' 'ธงชัย' 'คลองกระแชง' 'ช่องสะแก' 'ท่าราบ'
#  'นาวุ้ง' 'โพไร่หวาน' 'ชะอำ' 'หนองปลาไหล' 'คลองโยง' 'พญาไท' 'ปากน้ำโพ'
#  'กุดตาเพชร' 'ฉลอง' 'โคกตูม' 'ช้างม่อย' 'เกาะยาวน้อย' 'พงสวาย' 'กมลา'
#  'ทุ่งกระตาดพัฒนา' 'ขามทะเลสอ' 'แคราย' 'บางรักใหญ่' 'หนองปรือ' 'แสนสุข'
#  'พระโขนงใต้' 'ตลาด' 'เสาธงหิน' 'บ้านโพธิ์' 'หอรัตนไชย' 'ป่าตอง' 'คลองสาม'
#  'คลองเกลือ' 'ตลาดเหนือ' 'บางเมือง' 'พิมลราช' 'ในเวียง' 'แพรกษาใหม่'
#  'บางบ่อ' 'ท้ายบ้าน' 'ศิลา' 'บางโฉลง' 'บางใหญ่' 'รัชดาภิเษก'
#  'บางเมืองใหม่' 'สามร้อยยอด' 'บ้านหม้อ' 'บางหลวง' 'มหาชัย' 'แพรกษา'
#  'ท่าตลาด' 'ศาลาแดง' 'หนองอ้อ' 'ดอนขุนห้วย' 'อ่อนนุช' 'ห้วยใหญ่' 'ไทรน้อย'
#  'ไร่ขิง' 'ควนลัง' 'แช่ช้าง' 'ทุ่งสุขลา' 'สันนาเม็ง']
# (330,)
# district ['ประเวศ' 'สาทร' 'ลาดพร้าว' 'ดุสิต' 'สายไหม' 'ราชเทวี' 'บางรัก' 'จตุจักร'
#  'บางแค' 'บางกอกน้อย' 'คลองเตย' 'ลาดกระบัง' 'หลักสี่' 'บางกะปิ' 'หนองจอก'
#  'วัฒนา' 'บางเขน' 'คลองสาน' 'บางซื่อ' 'ราษฎร์บูรณะ' 'ดินแดง' 'ธนบุรี'
#  'ปทุมวัน' 'คันนายาว' 'พระนคร' 'ตลิ่งชัน' 'ดอนเมือง' 'ห้วยขวาง' 'สะพานสูง'
#  'พญาไท' 'สวนหลวง' 'ภาษีเจริญ' 'บางขุนเทียน' 'บางคอแหลม' 'บางนา' 'ทุ่งครุ'
#  'จอมทอง' 'คลองสามวา' 'วังทองหลาง' 'บางกอกใหญ่' 'ยานนาวา' 'พระโขนง'
#  'บึงกุ่ม' 'หนองแขม' 'มีนบุรี' 'บางพลัด' 'บางบอน' 'สัมพันธวงศ์'
#  'ป้อมปราบศัตรูพ่าย' 'บางกรวย' 'ทวีวัฒนา' 'พระประแดง' 'เมืองสมุทรสาคร'
#  'บางเสาธง' 'เมืองปทุมธานี' 'กระทุ่มแบน' 'บางพลี' 'เมืองนนทบุรี'
#  'เมืองสมุทรปราการ' 'สามพราน' 'ปากเกร็ด' 'ธัญบุรี' 'พุทธมณฑล'
#  'ศรีประจันต์' 'คลองหลวง' 'เมืองเชียงราย' 'บางใหญ่' 'เมืองนครปฐม'
#  'บางละมุง' 'บางบ่อ' 'เมืองชุมพร' 'ลำลูกกา' 'บางน้ำเปรี้ยว'
#  'พระสมุทรเจดีย์' 'ดอนตูม' 'เมืองนครศรีธรรมราช' 'พยุหะคีรี' 'หาดใหญ่'
#  'บ้านธิ' 'ลาดหลุมแก้ว' 'พรหมพิราม' 'เมืองภูเก็ต' 'เมืองนครราชสีมา'
#  'แก่งคอย' 'เมืองราชบุรี' 'จะนะ' 'เมืองประจวบคีรีขันธ์' 'สามโคก' 'พุนพิน'
#  'บ้านหมี่' 'ดอยสะเก็ด' 'เลิงนกทา' 'ท่าม่วง' 'เกาะยาว' 'ไชยวาน' 'โพธาราม'
#  'เมืองเพชรบุรี' 'ชะอำ' 'เขาย้อย' 'เมืองสุรินทร์' 'เมืองนครสวรรค์'
#  'ลำสนธิ' 'เมืองลพบุรี' 'เมืองเชียงใหม่' 'กะทู้' 'หนองกี่' 'ขามทะเลสอ'
#  'บางบัวทอง' 'เมืองชลบุรี' 'เสนา' 'พระนครศรีอยุธยา' 'เมืองแพร่'
#  'เมืองขอนแก่น' 'สามร้อยยอด' 'บ้านโป่ง' 'ไทรน้อย' 'สันกำแพง' 'ศรีราชา'
#  'สันทราย']
# (119,)
# province ['กรุงเทพมหานคร' 'นนทบุรี' 'สมุทรปราการ' 'สมุทรสาคร' 'ปทุมธานี' 'นครปฐม'
#  'สุพรรณบุรี' 'เชียงราย' 'ชลบุรี' ' กรุงเทพมหานคร' 'พระนครศรีอยุธยา'
#  'นครศรีธรรมราช' 'ฉะเชิงเทรา' 'ชุมพร' 'นครสวรรค์' 'สงขลา' 'ลำพูน'
#  'พิษณุโลก' 'ภูเก็ต' 'นครราชสีมา' 'สระบุรี' 'ราชบุรี' 'ประจวบคีรีขันธ์'
#  'สุราษฎร์ธานี' 'ลพบุรี' 'เชียงใหม่' 'ยโสธร' 'กาญจนบุรี' 'พังงา'
#  'อุดรธานี' 'เพชรบุรี' 'สุรินทร์' 'พะเยา' 'ไม่ระบุ' 'บุรีรัมย์' 'แพร่'
#  'ขอนแก่น' 'อำนาจเจริญ' 'กระบี่']
# (39,)
# timestamp ['2021-09-19 14:56:08.924992+00' '2021-09-26 05:03:52.594898+00'
#  '2021-12-09 12:29:08.408763+00' ... '2025-01-16 02:52:33.878797+00'
#  '2025-01-16 02:53:27.583947+00' '2025-01-16 02:53:34.290375+00']
# (785925,)
# state ['เสร็จสิ้น' 'กำลังดำเนินการ' 'รอรับเรื่อง']
# (3,)
# star [ 4. nan  5.  2.  1.  3.]
# (6,)
# count_reopen [  0   1   2   4   5   3   9   7   6  14  10   8  39  18  12  11  13  28
#   26  15  22  20  17  19  42  40  16  80  23  37  54  21  25  47  35  50
#   34  33  24  29  31  36  59  81  93  30  43  27  41  73  44 100  65  53
#   45  61  32  88  48  38  57  58  67]
# (63,)
# last_activity ['2022-06-21 08:21:09.532782+00' '2022-06-06 01:17:12.272904+00'
#  '2022-08-12 07:18:44.884945+00' ... '2025-01-16 02:52:38.17364+00'
#  '2025-01-16 02:53:30.250517+00' '2025-01-16 02:58:02.568451+00']
# (785925,)
# latitude ['13.67891' '13.72060' '13.82280' ... '13.92269' '13.59140' '13.59766']
# (35215,)
# longitude ['100.66709' '100.52649' '100.59165' ... '100.79705' '100.83288'
#  '100.92399']
# (53269,)

# %% [markdown]
# # จัดการ type

# %%
# 1. สร้าง column ใหม่เพื่อเก็บ "จำนวน type" ในแต่ละแถว
# หลักการ: ลบปีกกา {} ออก -> แยกคำด้วยคอมม่า -> นับจำนวนสมาชิกที่แยกได้
lat_long['type_count'] = lat_long['type'].str.strip('{}').str.split(',').apply(len)

# --- คำตอบข้อที่ 1 และ 2: Row ที่มี type มากที่สุด ---
# หา index ของแถวที่มีค่า type_count สูงที่สุด
max_idx = lat_long['type_count'].idxmax()
row_max = lat_long.loc[max_idx]

print(f"Row ที่มี type มากที่สุดคือ Index: {max_idx}")
print(f"จำนวน type ใน Row นี้คือ: {row_max['type_count']}")
print(f"ค่าใน Row นี้คือ: {row_max['type']}")

print("-" * 30)

# --- คำตอบข้อที่ 3: ค่าเฉลี่ยของ type ต่อ 1 row ---
average_type = lat_long['type_count'].mean()

print(f"ค่าเฉลี่ยของ type ต่อ 1 row คือ: {average_type:.2f} ประเภท")
# Out:
# Row ที่มี type มากที่สุดคือ Index: 651748
# จำนวน type ใน Row นี้คือ: 24
# ค่าใน Row นี้คือ: {สายไฟ,สัตว์จรจัด,ความสะอาด,เสียงรบกวน,น้ำท่วม,แสงสว่าง,สอบถาม,คนจรจัด,ร้องเรียน,ป้าย,ท่อระบายน้ำ,คลอง,PM2.5,กีดขวาง,เสนอแนะ,ห้องน้ำ,การเดินทาง,ต้นไม้,จราจร,สะพาน,ป้ายจราจร,ทางเท้า,ความปลอดภัย,ถนน}
# ------------------------------
# ค่าเฉลี่ยของ type ต่อ 1 row คือ: 1.51 ประเภท
# /tmp/ipython-input-424608788.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_long['type_count'] = lat_long['type'].str.strip('{}').str.split(',').apply(len)

# %%
# สมมติว่า df คือ DataFrame ของคุณ
# ขั้นตอนที่ 1: ลบปีกกา {} และแยกข้อมูลด้วยคอมม่า (,)
# expand=True จะทำให้ผลลัพธ์ออกมาเป็น DataFrame แยก column ให้เลย
split_types = lat_long['type'].str.strip('{}').str.split(',', expand=True)

# ขั้นตอนที่ 2: บังคับให้เอาแค่ 3 column แรก (0, 1, 2)
# ถ้าข้อมูลเดิมมีแค่ 1 หรือ 2 ตัว columns ที่ขาดจะถูกเติมด้วย NaN (null)
# ถ้าข้อมูลเดิมมีเกิน 3 ตัว ส่วนเกินจะถูกตัดทิ้ง
split_types = split_types.reindex(columns=[0, 1, 2])

# ขั้นตอนที่ 3: ตั้งชื่อ column ใหม่ และนำไปใส่ใน DataFrame หลัก
lat_long[['type 1', 'type 2', 'type 3']] = split_types
# Out:
# /tmp/ipython-input-3145624745.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_long[['type 1', 'type 2', 'type 3']] = split_types
# /tmp/ipython-input-3145624745.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_long[['type 1', 'type 2', 'type 3']] = split_types
# /tmp/ipython-input-3145624745.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_long[['type 1', 'type 2', 'type 3']] = split_types

# %%
clean_type = lat_long

display(clean_type.head(10))
display(clean_type.tail(10))
# Out:
#       ticket_id                 type  \
# 1   2021-CGPMUN  {น้ำท่วม,ร้องเรียน}
# 2   2021-7XATFA              {สะพาน}
# 4   2021-DVEWYM        {น้ำท่วม,ถนน}
# 5   2021-4D9Y98                   {}
# 6   2021-7U9RED                   {}
# 7   2021-8N9ZP8          {ความสะอาด}
# 8   2021-7K6QA3                   {}
# 9   2021-8BTWZB        {ท่อระบายน้ำ}
# 10  2021-AKJBCU                   {}
# 11  2021-EQWYWT          {ความสะอาด}
#
#                                          organization  \
# 1                        เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2                                             เขตสาทร
# 4                    เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 5            เขตลาดพร้าว,การไฟฟ้านครหลวง เขตนวลจันทร์
# 6                                            เขตดุสิต
# 7   เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ,ฝ่ายรักษาความสะ...
# 8                      เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ
# 9                        เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 10                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 11  เขตประเวศ,สำนักสิ่งแวดล้อม กทม.,ฝ่ายสิ่งแวดล้อ...
#
#                                               comment  \
# 1   น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2     สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 4   ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 5                         หน้าปากซอย ลาดพร้าววังหิน26
# 6   ยังไม่มีหน่วยงานไหนมาดูแลครับ รถจะเชี่ยวหลายคน...
# 7                   คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 8   ระยะหลังๆ นี้ พบเจอรถสิบล้อขนดิน ใส่ยางบังโคลน...
# 9   ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
# 10  แจ้งเรื่องพื้นผิวถนนเสียหาย มีการพยายามซ่อมแซม...
# 11     ปัญหากลิ่นขยะจากโรงขยะ 800 ตัน อ่อนนุช 86 ครับ
#
#                                                 photo  \
# 1   https://storage.googleapis.com/traffy_public_b...
# 2   https://storage.googleapis.com/traffy_public_b...
# 4   https://storage.googleapis.com/traffy_public_b...
# 5   https://storage.googleapis.com/traffy_public_b...
# 6   https://storage.googleapis.com/traffy_public_b...
# 7   https://storage.googleapis.com/traffy_public_b...
# 8   https://storage.googleapis.com/traffy_public_b...
# 9   https://storage.googleapis.com/traffy_public_b...
# 10  https://storage.googleapis.com/traffy_public_b...
# 11  https://storage.googleapis.com/traffy_public_b...
#
#                                           photo_after              coords  \
# 1   https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                 NaN  100.52649,13.72060
# 4                                                 NaN  100.59165,13.82280
# 5   https://storage.googleapis.com/traffy_public_b...  100.59131,13.80910
# 6   https://storage.googleapis.com/traffy_public_b...  100.50848,13.77832
# 7   https://storage.googleapis.com/traffy_public_b...  100.64690,13.67083
# 8   https://storage.googleapis.com/traffy_public_b...  100.65617,13.72812
# 9   https://storage.googleapis.com/traffy_public_b...  100.65440,13.68158
# 10  https://storage.googleapis.com/traffy_public_b...  100.64844,13.68735
# 11  https://storage.googleapis.com/traffy_public_b...  100.68837,13.71887
#
#                                               address subdistrict  district  \
# 1   189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2   191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 4   702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 5   17/73 17/73 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขต...    ลาดพร้าว  ลาดพร้าว
# 6   627 ถนนสามเสน แขวง ดุสิต เขตดุสิต กรุงเทพมหานค...       ดุสิต     ดุสิต
# 7   110 ซอย มีสุข แขวง หนองบอน เขต ประเวศ กรุงเทพม...     หนองบอน    ประเวศ
# 8   208/22 ถ. พัฒนาการ แขวง ประเวศ เขต ประเวศ กรุง...      ประเวศ    ประเวศ
# 9   70 ซอย เฉลิมพระเกียรติ ร. 9 แขวง หนองบอน เขต ป...     หนองบอน    ประเวศ
# 10  55 ถนน ศรีนครินทร์ แขวง หนองบอน เขต ประเวศ กรุ...     หนองบอน    ประเวศ
# 11  22/1 ซอย อ่อนนุช 86 แยก 2 แขวง ประเวศ เขต ประเ...      ประเวศ    ประเวศ
#
#     ...      state star count_reopen                  last_activity  latitude  \
# 1   ...  เสร็จสิ้น  4.0            0  2022-06-21 08:21:09.532782+00  13.67891
# 2   ...  เสร็จสิ้น  NaN            0  2022-06-06 01:17:12.272904+00  13.72060
# 4   ...  เสร็จสิ้น  5.0            0  2022-08-12 07:18:44.884945+00  13.82280
# 5   ...  เสร็จสิ้น  NaN            0  2023-03-14 12:09:14.947437+00  13.80910
# 6   ...  เสร็จสิ้น  5.0            0  2023-05-17 06:11:32.463984+00  13.77832
# 7   ...  เสร็จสิ้น  2.0            0  2024-11-26 04:17:39.760344+00  13.67083
# 8   ...  เสร็จสิ้น  2.0            0  2022-06-24 06:32:34.671236+00  13.72812
# 9   ...  เสร็จสิ้น  5.0            0   2022-06-20 13:12:04.99444+00  13.68158
# 10  ...  เสร็จสิ้น  NaN            0  2022-09-28 08:35:36.703421+00  13.68735
# 11  ...  เสร็จสิ้น  4.0            0   2022-07-12 06:50:02.31526+00  13.71887
#
#     longitude type_count       type 1     type 2 type 3
# 1   100.66709          2      น้ำท่วม  ร้องเรียน   None
# 2   100.52649          1        สะพาน       None   None
# 4   100.59165          2      น้ำท่วม        ถนน   None
# 5   100.59131          1                    None   None
# 6   100.50848          1                    None   None
# 7   100.64690          1    ความสะอาด       None   None
# 8   100.65617          1                    None   None
# 9   100.65440          1  ท่อระบายน้ำ       None   None
# 10  100.64844          1                    None   None
# 11  100.68837          1    ความสะอาด       None   None
#
# [10 rows x 22 columns]
#           ticket_id                                  type  \
# 787016       HJHFGC                     {ถนน,ความปลอดภัย}
# 787017  2025-CBCTHW                                    {}
# 787018       VFJ8NW  {ร้องเรียน,ถนน,ความปลอดภัย,แสงสว่าง}
# 787019  2025-9UU3KK                             {ทางเท้า}
# 787020  2025-H387A2                           {ถนน,PM2.5}
# 787021       KDDNBP                           {ร้องเรียน}
# 787022       RYM99G                       {ความสะอาด,ถนน}
# 787023  2025-BDQ87Y        {ร้องเรียน,ต้นไม้,ความปลอดภัย}
# 787024       EZCZZU                                 {ถนน}
# 787025  2025-E7CTFD                               {จราจร}
#
#                                              organization  \
# 787016       เขตประเวศ,ศูนย์ควบคุมระบบป้องกันน้ำท่วม กทม.
# 787017                                         เขตหลักสี่
# 787018                                          เขตดินแดง
# 787019  เขตจตุจักร,สำนักการโยธา กทม.,สำนักงานก่อสร้างแ...
# 787020                   เขตคลองเตย,สำนักสิ่งแวดล้อม กทม.
# 787021                                         เขตหนองจอก
# 787022             เขตคลองสาน,ฝ่ายสิ่งแวดล้อมฯ เขตคลองสาน
# 787023                                         เขตราชเทวี
# 787024                                          เขตจอมทอง
# 787025  เขตสวนหลวง,สำนักการจราจรและขนส่ง กรุงเทพมหานคร...
#
#                                                   comment  \
# 787016  ปัญหา: เบสท์ ปากซอยดังกล่าว พบฝาท่อระบายน้ำ(ลั...
# 787017  เหตุรำคาญ จากการใช้ส่วนต่อเติมของอาคารผิดพรบ.\...
# 787018  ศูนย์เรื่องราวร้องทุกข์ ได้รับการประสานผ่านระบ...
# 787019                 พื้นผิว ทางเท้า แตก แยก เป็นทางยาว
# 787020  เขตก่อสร้างโครงคอนโดแสนสิริซอยสุขุมวิท34 ทำให้...
# 787021  ศูนย์เรื่องราวร้องทุกข์ ได้รับการประสานผ่านระบ...
# 787022  ปัญหา: บริเวณตลาดพระเครื่องพญาไม้ พบร้านอาหารต...
# 787023  ต้นไม้บริเวณดังกล่าวช่วงโคนต้นไม้มันแห้งเหมือน...
# 787024  ปัญหา: พบโรงกลึง (ไม่ทราบชื่อ) ทำงานบนพื้นผิวจ...
# 787025  จริงๆไม่ใช่เขตสวนหลวงแต่ที่ปักเป็นสวนหลวงเพราะ...
#
#                                                     photo photo_after  \
# 787016  https://storage.googleapis.com/traffy_public_b...         NaN
# 787017  https://storage.googleapis.com/traffy_public_b...         NaN
# 787018  https://storage.googleapis.com/traffy_public_b...         NaN
# 787019  https://storage.googleapis.com/traffy_public_b...         NaN
# 787020  https://storage.googleapis.com/traffy_public_b...         NaN
# 787021  https://storage.googleapis.com/traffy_public_b...         NaN
# 787022  https://storage.googleapis.com/traffy_public_b...         NaN
# 787023  https://storage.googleapis.com/traffy_public_b...         NaN
# 787024  https://storage.googleapis.com/traffy_public_b...         NaN
# 787025  https://storage.googleapis.com/traffy_public_b...         NaN
#
#                     coords                                            address  \
# 787016  100.67219,13.69416  45 ซอย ถนน เฉลิมพระเกียรติ ร. 9 แขวงหนองบอน เข...
# 787017  100.54808,13.85436  ซอย งามวงศ์วาน 30 ถนน งามวงศ์วาน แขวง ทุ่งสองห...
# 787018  100.55596,13.77114  สำนักการโยธา ถนน สุขเกษม แขวงดินแดง เขตดินแดง ...
# 787019  100.56906,13.80853  62/2 ซอย ลาดพร้าว 14 แขวงจอมพล เขตจตุจักร กรุง...
# 787020  100.57473,13.72480  15 ถ. สุขุมวิท แขวงคลองตัน เขตคลองเตย กรุงเทพม...
# 787021  100.86304,13.85633  เขตหนองจอก กรุงเทพมหานคร : VV47+G6M แขวงกระทุ่...
# 787022  100.49651,13.73469  39 ถ. สมเด็จเจ้าพระยา แขวงสมเด็จเจ้าพระยา เขตค...
# 787023  100.53975,13.76426  10 ถ. ราชวิถี แขวงถนนพญาไท เขตราชเทวี กรุงเทพม...
# 787024  100.46226,13.67672  123 แขวงบางมด เขตจอมทอง กรุงเทพมหานคร 10150 ปร...
# 787025  100.65165,13.73036  2998 ถ. พัฒนาการ แขวงสวนหลวง เขตสวนหลวง กรุงเท...
#
#             subdistrict district  ...           state star count_reopen  \
# 787016          หนองบอน   ประเวศ  ...  กำลังดำเนินการ  NaN            0
# 787017      ทุ่งสองห้อง  หลักสี่  ...     รอรับเรื่อง  NaN            0
# 787018           ดินแดง   ดินแดง  ...  กำลังดำเนินการ  NaN            0
# 787019            จอมพล  จตุจักร  ...  กำลังดำเนินการ  NaN            0
# 787020          คลองตัน  คลองเตย  ...     รอรับเรื่อง  NaN            0
# 787021       กระทุ่มราย  หนองจอก  ...  กำลังดำเนินการ  NaN            0
# 787022  สมเด็จเจ้าพระยา  คลองสาน  ...  กำลังดำเนินการ  NaN            0
# 787023         ถนนพญาไท  ราชเทวี  ...     รอรับเรื่อง  NaN            0
# 787024            บางมด   จอมทอง  ...  กำลังดำเนินการ  NaN            0
# 787025          สวนหลวง  สวนหลวง  ...  กำลังดำเนินการ  NaN            0
#
#                         last_activity  latitude  longitude type_count  \
# 787016  2025-01-16 02:46:34.842222+00  13.69416  100.67219          2
# 787017  2025-01-16 02:46:48.092725+00  13.85436  100.54808          1
# 787018    2025-01-16 02:47:10.2788+00  13.77114  100.55596          4
# 787019  2025-01-16 02:50:43.327799+00  13.80853  100.56906          1
# 787020  2025-01-16 02:48:16.413097+00  13.72480  100.57473          2
# 787021  2025-01-16 02:50:26.781334+00  13.85633  100.86304          1
# 787022  2025-01-16 02:53:23.119455+00  13.73469  100.49651          2
# 787023   2025-01-16 02:52:38.17364+00  13.76426  100.53975          3
# 787024  2025-01-16 02:53:30.250517+00  13.67672  100.46226          1
# 787025  2025-01-16 02:58:02.568451+00  13.73036  100.65165          1
#
#            type 1       type 2       type 3
# 787016        ถนน  ความปลอดภัย         None
# 787017                    None         None
# 787018  ร้องเรียน          ถนน  ความปลอดภัย
# 787019    ทางเท้า         None         None
# 787020        ถนน        PM2.5         None
# 787021  ร้องเรียน         None         None
# 787022  ความสะอาด          ถนน         None
# 787023  ร้องเรียน       ต้นไม้  ความปลอดภัย
# 787024        ถนน         None         None
# 787025      จราจร         None         None
#
# [10 rows x 22 columns]

# %%
clean_type[clean_type['type 1'] == ""].shape
# Out:
# (115001, 22)

# %%
clean_type = clean_type[clean_type['type 1'] != ""]
clean_type.shape
# Out:
# (670924, 22)

# %%
clean_type.head()
# Out:
#      ticket_id                 type  \
# 1  2021-CGPMUN  {น้ำท่วม,ร้องเรียน}
# 2  2021-7XATFA              {สะพาน}
# 4  2021-DVEWYM        {น้ำท่วม,ถนน}
# 7  2021-8N9ZP8          {ความสะอาด}
# 9  2021-8BTWZB        {ท่อระบายน้ำ}
#
#                                         organization  \
# 1                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2                                            เขตสาทร
# 4                   เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 7  เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ,ฝ่ายรักษาความสะ...
# 9                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
#
#                                              comment  \
# 1  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 4  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 7                  คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 9  ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
#
#                                                photo  \
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# 4  https://storage.googleapis.com/traffy_public_b...
# 7  https://storage.googleapis.com/traffy_public_b...
# 9  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 1  https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                NaN  100.52649,13.72060
# 4                                                NaN  100.59165,13.82280
# 7  https://storage.googleapis.com/traffy_public_b...  100.64690,13.67083
# 9  https://storage.googleapis.com/traffy_public_b...  100.65440,13.68158
#
#                                              address subdistrict  district  \
# 1  189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2  191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 4  702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 7  110 ซอย มีสุข แขวง หนองบอน เขต ประเวศ กรุงเทพม...     หนองบอน    ประเวศ
# 9  70 ซอย เฉลิมพระเกียรติ ร. 9 แขวง หนองบอน เขต ป...     หนองบอน    ประเวศ
#
#    ...      state star count_reopen                  last_activity  latitude  \
# 1  ...  เสร็จสิ้น  4.0            0  2022-06-21 08:21:09.532782+00  13.67891
# 2  ...  เสร็จสิ้น  NaN            0  2022-06-06 01:17:12.272904+00  13.72060
# 4  ...  เสร็จสิ้น  5.0            0  2022-08-12 07:18:44.884945+00  13.82280
# 7  ...  เสร็จสิ้น  2.0            0  2024-11-26 04:17:39.760344+00  13.67083
# 9  ...  เสร็จสิ้น  5.0            0   2022-06-20 13:12:04.99444+00  13.68158
#
#    longitude type_count       type 1     type 2 type 3
# 1  100.66709          2      น้ำท่วม  ร้องเรียน   None
# 2  100.52649          1        สะพาน       None   None
# 4  100.59165          2      น้ำท่วม        ถนน   None
# 7  100.64690          1    ความสะอาด       None   None
# 9  100.65440          1  ท่อระบายน้ำ       None   None
#
# [5 rows x 22 columns]

# %%
clean_type = clean_type.drop(columns=['type', 'type_count'])

# %%
print(clean_type.columns)
display(clean_type.head())
# Out:
# Index(['ticket_id', 'organization', 'comment', 'photo', 'photo_after',
#        'coords', 'address', 'subdistrict', 'district', 'province', 'timestamp',
#        'state', 'star', 'count_reopen', 'last_activity', 'latitude',
#        'longitude', 'type 1', 'type 2', 'type 3'],
#       dtype='object')
#      ticket_id                                       organization  \
# 1  2021-CGPMUN                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2  2021-7XATFA                                            เขตสาทร
# 4  2021-DVEWYM                   เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 7  2021-8N9ZP8  เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ,ฝ่ายรักษาความสะ...
# 9  2021-8BTWZB                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
#
#                                              comment  \
# 1  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 4  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 7                  คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 9  ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
#
#                                                photo  \
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# 4  https://storage.googleapis.com/traffy_public_b...
# 7  https://storage.googleapis.com/traffy_public_b...
# 9  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 1  https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                NaN  100.52649,13.72060
# 4                                                NaN  100.59165,13.82280
# 7  https://storage.googleapis.com/traffy_public_b...  100.64690,13.67083
# 9  https://storage.googleapis.com/traffy_public_b...  100.65440,13.68158
#
#                                              address subdistrict  district  \
# 1  189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2  191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 4  702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 7  110 ซอย มีสุข แขวง หนองบอน เขต ประเวศ กรุงเทพม...     หนองบอน    ประเวศ
# 9  70 ซอย เฉลิมพระเกียรติ ร. 9 แขวง หนองบอน เขต ป...     หนองบอน    ประเวศ
#
#         province                      timestamp      state  star  \
# 1  กรุงเทพมหานคร  2021-09-19 14:56:08.924992+00  เสร็จสิ้น   4.0
# 2  กรุงเทพมหานคร  2021-09-26 05:03:52.594898+00  เสร็จสิ้น   NaN
# 4  กรุงเทพมหานคร  2021-12-09 12:29:08.408763+00  เสร็จสิ้น   5.0
# 7  กรุงเทพมหานคร  2021-12-18 14:50:52.437512+00  เสร็จสิ้น   2.0
# 9  กรุงเทพมหานคร  2021-12-22 10:15:33.294829+00  เสร็จสิ้น   5.0
#
#    count_reopen                  last_activity  latitude  longitude  \
# 1             0  2022-06-21 08:21:09.532782+00  13.67891  100.66709
# 2             0  2022-06-06 01:17:12.272904+00  13.72060  100.52649
# 4             0  2022-08-12 07:18:44.884945+00  13.82280  100.59165
# 7             0  2024-11-26 04:17:39.760344+00  13.67083  100.64690
# 9             0   2022-06-20 13:12:04.99444+00  13.68158  100.65440
#
#         type 1     type 2 type 3
# 1      น้ำท่วม  ร้องเรียน   None
# 2        สะพาน       None   None
# 4      น้ำท่วม        ถนน   None
# 7    ความสะอาด       None   None
# 9  ท่อระบายน้ำ       None   None

# %%
clean_type.shape
# Out:
# (670924, 20)

# %%
clean_organization = clean_type

# %%
# สมมติว่า DataFrame ของคุณชื่อ df
# 1. สร้างคอลัมน์ใหม่เพื่อนับจำนวน organization ในแต่ละแถว
# โดยการสั่ง split ด้วย ',' และนับความยาวของลิสต์ที่ได้
clean_organization['org_count'] = clean_organization['organization'].str.split(',').apply(len)

# 2. แสดง row ที่มี organization มากสุด
row_with_max_org = clean_organization[clean_organization['org_count'] == clean_organization['org_count'].max()]
print("Row ที่มี organization มากที่สุด:")
display(row_with_max_org)

# 3. ค่าเฉลี่ย organization ต่อ 1 row
average_org = clean_organization['org_count'].mean()
print(f"ค่าเฉลี่ย organization ต่อ 1 row: {average_org}")
# Out:
# Row ที่มี organization มากที่สุด:
#           ticket_id                                       organization  \
# 579208  2024-93E7XH  Chula TUN-JAI สำนักบริหารระบบกายภาพ,โรงเรียนสา...
#
#                                          comment  \
# 579208  สายไฟห้อยลงมาทั้งเส้น ไฟฟ้าริมถนนหักลงมา
#
#                                                     photo  \
# 579208  https://storage.googleapis.com/traffy_public_b...
#
#                                               photo_after              coords  \
# 579208  https://storage.googleapis.com/traffy_public_b...  100.52757,13.74317
#
#                                                   address subdistrict  \
# 579208  20 ซอย จุฬาลงกรณ์ 12 แขวงวังใหม่ เขตปทุมวัน กร...     วังใหม่
#
#        district       province  ...      state star  count_reopen  \
# 579208  ปทุมวัน  กรุงเทพมหานคร  ...  เสร็จสิ้น  4.0             0
#
#                         last_activity  latitude  longitude type 1 type 2  \
# 579208  2024-06-07 05:12:03.492795+00  13.74317  100.52757  สายไฟ   None
#
#        type 3 org_count
# 579208   None       101
#
# [1 rows x 21 columns]
# ค่าเฉลี่ย organization ต่อ 1 row: 3.3516270099146848

# %%
# 1. แยกข้อความด้วย comma (,) และกระจายออกเป็น DataFrame ชั่วคราว
# expand=True จะเปลี่ยน list ให้เป็น columns
split_df = clean_organization['organization'].str.split(',', expand=True)

# 2. สร้าง Column organization_1, 2, 3
# เราต้องเช็คด้วยว่า split_df มีคอลัมน์ครบมั้ย (ป้องกัน Error กรณีข้อมูลทุกแถวมีแค่ 1 organization)

clean_organization['organization_1'] = split_df[0] if 0 in split_df.columns else None
clean_organization['organization_2'] = split_df[1] if 1 in split_df.columns else None
clean_organization['organization_3'] = split_df[2] if 2 in split_df.columns else None

# %%
clean_organization.columns
#org_count organization
# Out:
# Index(['ticket_id', 'organization', 'comment', 'photo', 'photo_after',
#        'coords', 'address', 'subdistrict', 'district', 'province', 'timestamp',
#        'state', 'star', 'count_reopen', 'last_activity', 'latitude',
#        'longitude', 'type 1', 'type 2', 'type 3', 'org_count',
#        'organization_1', 'organization_2', 'organization_3'],
#       dtype='object')

# %%
clean_organization = clean_organization.drop(columns=['org_count', 'organization'])

# %%
clean_organization = clean_organization.drop(columns=['coords'])

# %%
display(clean_organization.head(10))
# Out:
#       ticket_id                                            comment  \
# 1   2021-CGPMUN  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2   2021-7XATFA    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 4   2021-DVEWYM  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 7   2021-8N9ZP8                  คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 9   2021-8BTWZB  ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
# 11  2021-EQWYWT     ปัญหากลิ่นขยะจากโรงขยะ 800 ตัน อ่อนนุช 86 ครับ
# 12  2022-7ZTKJV  บริเวณนราธิวาส  แยกถนนจันทน์ ใกล้สวนสาธารณะช่อ...
# 15  2022-HB7Z8A  ทางเท้าช่วง จันทน์ 18/5 สภาพโอเค แต่ฝาท่อเก่าแ...
# 17  2022-8PL3NK  ถนนจันทน์ช่วงสะพานสามถึงจันทน์ 18/5 น่าจะลาดยา...
# 19  2022-GNTHRA  ริมถนน ตรงสะพานสามช่วงจันทน์ 18/6-18/4 ชอบมีรถ...
#
#                                                 photo  \
# 1   https://storage.googleapis.com/traffy_public_b...
# 2   https://storage.googleapis.com/traffy_public_b...
# 4   https://storage.googleapis.com/traffy_public_b...
# 7   https://storage.googleapis.com/traffy_public_b...
# 9   https://storage.googleapis.com/traffy_public_b...
# 11  https://storage.googleapis.com/traffy_public_b...
# 12  https://storage.googleapis.com/traffy_public_b...
# 15  https://storage.googleapis.com/traffy_public_b...
# 17  https://storage.googleapis.com/traffy_public_b...
# 19  https://storage.googleapis.com/traffy_public_b...
#
#                                           photo_after  \
# 1   https://storage.googleapis.com/traffy_public_b...
# 2                                                 NaN
# 4                                                 NaN
# 7   https://storage.googleapis.com/traffy_public_b...
# 9   https://storage.googleapis.com/traffy_public_b...
# 11  https://storage.googleapis.com/traffy_public_b...
# 12  https://storage.googleapis.com/traffy_public_b...
# 15                                                NaN
# 17  https://storage.googleapis.com/traffy_public_b...
# 19                                                NaN
#
#                                               address subdistrict  district  \
# 1   189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2   191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 4   702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 7   110 ซอย มีสุข แขวง หนองบอน เขต ประเวศ กรุงเทพม...     หนองบอน    ประเวศ
# 9   70 ซอย เฉลิมพระเกียรติ ร. 9 แขวง หนองบอน เขต ป...     หนองบอน    ประเวศ
# 11  22/1 ซอย อ่อนนุช 86 แยก 2 แขวง ประเวศ เขต ประเ...      ประเวศ    ประเวศ
# 12  แยกจันทน์-นราธิวาส ถนน จันทน์ แขวง ทุ่งมหาเมฆ ...  ทุ่งมหาเมฆ      สาทร
# 15  1357/1-4 ซอย จันทน์ 23/2 แขวง ทุ่งวัดดอน เขต ส...  ทุ่งวัดดอน      สาทร
# 17  1357/1-4 ซอย จันทน์ 23/2 แขวง ทุ่งวัดดอน เขต ส...  ทุ่งวัดดอน      สาทร
# 19  3 ซอย จันทน์ 18/4 แขวง ทุ่งวัดดอน เขต สาทร กรุ...  ทุ่งวัดดอน      สาทร
#
#          province                      timestamp           state  ...  \
# 1   กรุงเทพมหานคร  2021-09-19 14:56:08.924992+00       เสร็จสิ้น  ...
# 2   กรุงเทพมหานคร  2021-09-26 05:03:52.594898+00       เสร็จสิ้น  ...
# 4   กรุงเทพมหานคร  2021-12-09 12:29:08.408763+00       เสร็จสิ้น  ...
# 7   กรุงเทพมหานคร  2021-12-18 14:50:52.437512+00       เสร็จสิ้น  ...
# 9   กรุงเทพมหานคร  2021-12-22 10:15:33.294829+00       เสร็จสิ้น  ...
# 11  กรุงเทพมหานคร  2021-12-28 03:59:06.003252+00       เสร็จสิ้น  ...
# 12  กรุงเทพมหานคร  2022-01-02 10:53:25.580723+00       เสร็จสิ้น  ...
# 15  กรุงเทพมหานคร  2022-01-14 01:32:03.715912+00  กำลังดำเนินการ  ...
# 17  กรุงเทพมหานคร  2022-01-16 10:57:39.184772+00       เสร็จสิ้น  ...
# 19  กรุงเทพมหานคร  2022-01-16 11:08:54.141813+00       เสร็จสิ้น  ...
#
#     count_reopen                  last_activity  latitude  longitude  \
# 1              0  2022-06-21 08:21:09.532782+00  13.67891  100.66709
# 2              0  2022-06-06 01:17:12.272904+00  13.72060  100.52649
# 4              0  2022-08-12 07:18:44.884945+00  13.82280  100.59165
# 7              0  2024-11-26 04:17:39.760344+00  13.67083  100.64690
# 9              0   2022-06-20 13:12:04.99444+00  13.68158  100.65440
# 11             0   2022-07-12 06:50:02.31526+00  13.71887  100.68837
# 12             0  2022-06-08 05:46:12.776594+00  13.70716  100.53764
# 15             0  2022-09-15 15:51:15.433811+00  13.70566  100.53025
# 17             0  2023-08-18 06:52:20.549786+00  13.70569  100.52970
# 19             0  2022-06-23 08:06:52.928142+00  13.70615  100.52760
#
#          type 1     type 2 type 3 organization_1  \
# 1       น้ำท่วม  ร้องเรียน   None      เขตประเวศ
# 2         สะพาน       None   None        เขตสาทร
# 4       น้ำท่วม        ถนน   None    เขตลาดพร้าว
# 7     ความสะอาด       None   None      เขตประเวศ
# 9   ท่อระบายน้ำ       None   None      เขตประเวศ
# 11    ความสะอาด       None   None      เขตประเวศ
# 12          ถนน    ทางเท้า   None        เขตสาทร
# 15  ท่อระบายน้ำ    ทางเท้า   None        เขตสาทร
# 17          ถนน      สะพาน   None        เขตสาทร
# 19        สะพาน       None   None        เขตสาทร
#
#                                      organization_2  \
# 1                                ฝ่ายโยธา เขตประเวศ
# 2                                              None
# 4                              ฝ่ายโยธา เขตลาดพร้าว
# 7                              ฝ่ายเทศกิจ เขตประเวศ
# 9                                ฝ่ายโยธา เขตประเวศ
# 11                            สำนักสิ่งแวดล้อม กทม.
# 12                                 ฝ่ายโยธา เขตสาทร
# 15                            สำนักการระบายน้ำ กทม.
# 17  สำนักการจราจรและขนส่ง กรุงเทพมหานคร (สจส. กทม.)
# 19                               ฝ่ายเทศกิจ เขตสาทร
#
#                    organization_3
# 1                            None
# 2                            None
# 4                            None
# 7   ฝ่ายรักษาความสะอาดฯ เขตประเวศ
# 9                            None
# 11     ฝ่ายสิ่งแวดล้อมฯ เขตประเวศ
# 12                           None
# 15               ฝ่ายโยธา เขตสาทร
# 17                           None
# 19                           None
#
# [10 rows x 21 columns]

# %%
for col in clean_organization.columns:
  print(col, clean_organization[clean_organization[col].isna()].shape)
# Out:
# ticket_id (6175, 21)
# comment (6175, 21)
# photo (77, 21)
# photo_after (119349, 21)
# address (6175, 21)
# subdistrict (0, 21)
# district (0, 21)
# province (0, 21)
# timestamp (0, 21)
# state (0, 21)
# star (442218, 21)
# count_reopen (0, 21)
# last_activity (0, 21)
# latitude (0, 21)
# longitude (0, 21)
# type 1 (0, 21)
# type 2 (389228, 21)
# type 3 (580455, 21)
# organization_1 (0, 21)
# organization_2 (20186, 21)
# organization_3 (280108, 21)

# %%
clean_organization.to_csv('/opt/airflow/data/clean_data2.csv', index=True, encoding='utf-8')
